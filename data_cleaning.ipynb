# %% [markdown]
# ## Data Cleaning using Pandas

# %%
# importing the required packages 
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\lenovo\Downloads\indian toys\indian_toy_market_sales_data.csv")
df.head()
# Out:
#         Transaction_ID Transaction_Date  Year  Month Month_Name Quarter  \
# 0  TXN-20230802-000000       2023-08-02  2023      8     August      Q3
# 1  TXN-20240412-000001       2024-04-12  2024      4      April      Q2
# 2  TXN-20220128-000002       2022-01-28  2022      1    January      Q1
# 3  TXN-20201012-000003       2020-10-12  2020     10    October      Q4
# 4  TXN-20211127-000004       2021-11-27  2021     11   November      Q4
#
#   Day_of_Week           Brand     Brand_Type   Product_Category  ...  \
# 0   Wednesday          OKPlay          Local          STEM Toys  ...
# 1      Friday           Lego   International      Arts & Crafts  ...
# 2      Friday  Funskool India  International        Board Games  ...
# 3      Monday          HASBRO  International          Soft Toys  ...
# 4    Saturday    Fisher Price  International  Construction Toys  ...
#
#   Unit_Price_INR Quantity Gross_Revenue_INR Discount_Percentage  \
# 0        3309.05        4          13236.20                 0.0
# 1         602.82        3           1808.46                 0.0
# 2        3171.93        1           3171.93                 0.0
# 3        1756.13        1           1756.13                 0.0
# 4        3616.34        2           7232.68                 0.0
#
#   Discount_Amount_INR Net_Revenue_INR Customer_Rating Safety_Certified  \
# 0                 0.0        13236.20             3.4             TRUE
# 1                 0.0         1808.46             4.1              NaN
# 2                 0.0         3171.93             4.3             TRUE
# 3                 0.0         1756.13             3.6              yes
# 4                 0.0         7232.68             4.7               No
#
#    Returned  Customer_Type
# 0        no            New
# 1        no      Returning
# 2       Yes      Returning
# 3       yes      Returning
# 4        no      Returning
#
# [5 rows x 28 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 28 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Transaction_ID       100000 non-null  object
#  1   Transaction_Date     100000 non-null  object
#  2   Year                 100000 non-null  int64
#  3   Month                100000 non-null  int64
#  4   Month_Name           100000 non-null  object
#  5   Quarter              100000 non-null  object
#  6   Day_of_Week          100000 non-null  object
#  7   Brand                100000 non-null  object
#  8   Brand_Type           100000 non-null  object
#  9   Product_Category     100000 non-null  object
#  10  Product_Subcategory  100000 non-null  object
#  11  Product_ID           100000 non-null  object
#  12  Region               98968 non-null   object
#  13  City                 100000 non-null  object
#  14  City_Tier            100000 non-null  object
#  15  Sales_Channel        100000 non-null  object
#  16  Channel_Type         100000 non-null  object
#  17  Target_Age_Group     100000 non-null  object
#  18  Unit_Price_INR       100000 non-null  float64
#  19  Quantity             100000 non-null  int64
#  20  Gross_Revenue_INR    100000 non-null  float64
#  21  Discount_Percentage  100000 non-null  float64
#  22  Discount_Amount_INR  100000 non-null  float64
#  23  Net_Revenue_INR      100000 non-null  float64
#  24  Customer_Rating      98021 non-null   float64
#  25  Safety_Certified     89984 non-null   object
#  26  Returned             95044 non-null   object
#  27  Customer_Type        97032 non-null   object
# dtypes: float64(6), int64(3), object(19)
# memory usage: 21.4+ MB

# %%
print(df.columns)
# Out:
# Index(['Transaction_ID', 'Transaction_Date', 'Year', 'Month', 'Month_Name',
#        'Quarter', 'Day_of_Week', 'Brand', 'Brand_Type', 'Product_Category',
#        'Product_Subcategory', 'Product_ID', 'Region', 'City', 'City_Tier',
#        'Sales_Channel', 'Channel_Type', 'Target_Age_Group', 'Unit_Price_INR',
#        'Quantity', 'Gross_Revenue_INR', 'Discount_Percentage',
#        'Discount_Amount_INR', 'Net_Revenue_INR', 'Customer_Rating',
#        'Safety_Certified', 'Returned', 'Customer_Type'],
#       dtype='object')

# %%
# changing column names to snake case
df.columns = df.columns.str.lower()

# %%
df.head()
# Out:
#         transaction_id transaction_date  year  month month_name quarter  \
# 0  TXN-20230802-000000       2023-08-02  2023      8     August      Q3
# 1  TXN-20240412-000001       2024-04-12  2024      4      April      Q2
# 2  TXN-20220128-000002       2022-01-28  2022      1    January      Q1
# 3  TXN-20201012-000003       2020-10-12  2020     10    October      Q4
# 4  TXN-20211127-000004       2021-11-27  2021     11   November      Q4
#
#   day_of_week           brand     brand_type   product_category  ...  \
# 0   Wednesday          OKPlay          Local          STEM Toys  ...
# 1      Friday           Lego   International      Arts & Crafts  ...
# 2      Friday  Funskool India  International        Board Games  ...
# 3      Monday          HASBRO  International          Soft Toys  ...
# 4    Saturday    Fisher Price  International  Construction Toys  ...
#
#   unit_price_inr quantity gross_revenue_inr discount_percentage  \
# 0        3309.05        4          13236.20                 0.0
# 1         602.82        3           1808.46                 0.0
# 2        3171.93        1           3171.93                 0.0
# 3        1756.13        1           1756.13                 0.0
# 4        3616.34        2           7232.68                 0.0
#
#   discount_amount_inr net_revenue_inr customer_rating safety_certified  \
# 0                 0.0        13236.20             3.4             TRUE
# 1                 0.0         1808.46             4.1              NaN
# 2                 0.0         3171.93             4.3             TRUE
# 3                 0.0         1756.13             3.6              yes
# 4                 0.0         7232.68             4.7               No
#
#    returned  customer_type
# 0        no            New
# 1        no      Returning
# 2       Yes      Returning
# 3       yes      Returning
# 4        no      Returning
#
# [5 rows x 28 columns]

# %%
df['safety_certified'] = df['safety_certified'].map({'TRUE': 'Yes',
                                                     'yes': 'Yes', 
                                                     'No':'No', 
                                                     'N':'No', 
                                                     'Y':'Yes', 
                                                     'no': 'No', 
                                                     'Yes':'Yes', 
                                                     'FALSE': 'No'})
print(f'safety_certified column cleaned.')
# Out:
# safety_certified column cleaned.

# %%
df['safety_certified'].unique()
# Out:
# array(['Yes', nan, 'No'], dtype=object)

# %% [markdown]
# ### Brand column

# %%
# cleaning the brand column 
df['brand'].unique()
# Out:
# array(['OKPlay', ' Lego ', 'Funskool India', 'HASBRO', 'Fisher Price',
#        'Lego', 'Nerf', 'HotWheels', 'Toyzone', 'OK Play', 'Hot Wheels',
#        'Barbie', 'Funskool', 'Hasbro', 'Skillmatics', 'Toy Zone', 'NERF',
#        'LEGO', 'BARBIE', 'Playshifu', 'Mattel', 'Fisher-Price', 'MATTEL',
#        ' Playshifu ', ' Skillmatics ', ' Hot Wheels ', ' Barbie ',
#        ' Hasbro ', ' Smartivity ', ' BARBIE ', 'Smartivity', ' MATTEL ',
#        ' Toy Zone ', ' Toyzone ', ' Funskool India ', ' OK Play ',
#        ' HotWheels ', ' Funskool ', ' Mattel ', ' Nerf ', ' NERF ',
#        ' LEGO ', ' OKPlay ', ' Fisher Price ', ' Fisher-Price ',
#        ' HASBRO '], dtype=object)

# %%
# trimming the right and left spaces 
df['brand'] = (df['brand'].str.strip())

# %%
df['brand'].unique()
# Out:
# array(['OKPlay', 'Lego', 'Funskool India', 'HASBRO', 'Fisher Price',
#        'Nerf', 'HotWheels', 'Toyzone', 'OK Play', 'Hot Wheels', 'Barbie',
#        'Funskool', 'Hasbro', 'Skillmatics', 'Toy Zone', 'NERF', 'LEGO',
#        'BARBIE', 'Playshifu', 'Mattel', 'Fisher-Price', 'MATTEL',
#        'Smartivity'], dtype=object)

# %%
df['brand'] = df['brand'].map({'OKPlay' : 'OK Play',
                       'Funskool India' : 'Funskool', 
                       'Lego' : 'Lego',
                       'Fisher Price': 'Fisher Price',
                       'HASBRO':'Hasbro', 
                       'Nerf' : 'Nerf',
                       'Funskool' : 'Funskool',
                       'OK Play' : 'OK Play',
                       'Hot Wheels' : 'Hot Wheels',
                       'Barbie' : 'Barbie',
                       'Hasbro' : 'Hasbro', 
                       'Skillmatics' : 'Skillmatics',
                       'Toy Zone' : 'Toy Zone',
                       'Playshifu' : 'Playshifu',
                       'Mattel' : 'Mattel',
                       'Smartivity': 'Smartivity',
                       'HotWheels' : 'Hot Wheels', 
                       'Toyzone' : 'Toy Zone',  
                       'NERF' : 'Nerf', 
                       'LEGO' : 'Lego',
                       'BARBIE' :'Barbie', 
                       'Fisher-Price' : 'Fisher Price', 
                       'MATTEL' : 'Mattel',
                       })

# %%
df['brand'].unique()
# Out:
# array(['OK Play', 'Lego', 'Funskool', 'Hasbro', 'Fisher Price', 'Nerf',
#        'Hot Wheels', 'Toy Zone', 'Barbie', 'Skillmatics', 'Playshifu',
#        'Mattel', 'Smartivity'], dtype=object)

# %% [markdown]
# ### city column

# %%
df['city'].unique()
# Out:
# array(['Delhi', 'Kolkata', 'Calcutta', 'Coimbatore', 'Noida', 'Gurugram',
#        'Kochi', 'Chandigarh', ' Kochi', 'Chennai', 'Bengaluru', ' Noida',
#        'Patna', 'Indore', 'Mumbai', ' Hyderabad', 'Bombay', ' Calcutta',
#        ' Kolkata', 'Ranchi', 'Ahmedabad', 'Mysore', 'Jaipur', 'Guwahati',
#        'Nagpur', 'Bangalore', 'Hyderabad', 'Pune', 'Surat', ' Ranchi',
#        'Bhubaneswar', 'Lucknow', ' Bengaluru', ' Coimbatore', ' Delhi',
#        ' Mysore', ' Guwahati', ' Surat', ' Chennai', ' Jaipur', ' Bombay',
#        ' Pune', ' Nagpur', ' Lucknow', ' Patna', ' Bhubaneswar',
#        ' Mumbai', ' Bangalore', ' Gurugram', ' Indore', ' Ahmedabad',
#        ' Chandigarh'], dtype=object)

# %%
# cleaning the city column 
df['city'] = df['city'].str.strip()

# %%
city_rename = {
    'Calcutta': 'Kolkata',
    'Bombay': 'Mumbai',
    'Bangalore': 'Bengaluru'
}
df['city'] = df['city'].replace(city_rename)

# %% [markdown]
# #### sales_channel column

# %%
df['sales_channel'].unique()
# Out:
# array(['Hamleys Store', 'flipkart', 'amazon.in', 'Hamleys', 'Amazon',
#        'Brand Website', 'Retail Chain', 'Local Toy Store', 'Flipkart',
#        'Website', 'FirstCry'], dtype=object)

# %%
# cleaning the sales_channel column 
channel_replace = {
    'Hamleys':'Hamleys Store',
    'amazon.in': 'Amazon',
    'flipkart' : 'Flipkart',
    'Website' : 'Brand Website'
}
df['sales_channel'] = df['sales_channel'].replace(channel_replace)

# %% [markdown]
# #### target_age_group column

# %%
df['target_age_group'].unique()
# Out:
# array(['13+', '9-12', '6-8 years', '13+ years', '3-5 years', '6-8', '0-2',
#        '9-12 years', '0-2 years', '3-5'], dtype=object)

# %%
age_group_replace = {
    '0-2' : '0-2 years',
    '3-5' : '3-5 years', 
    '6-8' : '6-8 years',
    '9-12' : '9-12 years',
    '13+' : '13+ years' 
}
df['target_age_group']= df['target_age_group'].replace(age_group_replace)

# %% [markdown]
# #### Quantity column

# %%
df['quantity'].unique()
# Out:
# array([ 4,  3,  1,  2, -1,  5, -2, -4, -3, -5])

# %%
df['quantity'] = df['quantity'].abs()

# %% [markdown]
# ####  returned column

# %%
df['returned'].unique()
# Out:
# array(['no', 'Yes', 'yes', 'N', 'Y', 'No', nan], dtype=object)

# %%
returned_std = {
    'yes' : 'Yes',
    'Y' : 'Yes',
    'N' : 'No',
    'no' : 'No'
}
df['returned'] = df['returned'].replace(returned_std)

# %% [markdown]
# #### cleaning the date column

# %%
# replacing / with - to standardize the transaction_date column 
df['transaction_date'] = df['transaction_date'].str.replace('/', '-').head(50)

# %%
print(df['transaction_date'].head(10))
# Out:
# 0    2023-08-02
# 1    2024-04-12
# 2    2022-01-28
# 3    2020-10-12
# 4    2021-11-27
# 5    2021-05-05
# 6    13-02-2020
# 7    2020-07-20
# 8    2022-02-15
# 9    2020-09-02
# Name: transaction_date, dtype: object

# %%
df['transaction_date'] = pd.to_datetime(df['transaction_date'], format = 'mixed', dayfirst=True)

# %%
# printing duplicates from the data 
print(df[df.duplicated()])
# Out:
# Empty DataFrame
# Columns: [transaction_id, transaction_date, year, month, month_name, quarter, day_of_week, brand, brand_type, product_category, product_subcategory, product_id, region, city, city_tier, sales_channel, channel_type, target_age_group, unit_price_inr, quantity, gross_revenue_inr, discount_percentage, discount_amount_inr, net_revenue_inr, customer_rating, safety_certified, returned, customer_type]
# Index: []
#
# [0 rows x 28 columns]

# %%
df.head(50)
# Out:
#          transaction_id transaction_date  year  month month_name quarter  \
# 0   TXN-20230802-000000       2023-08-02  2023      8     August      Q3
# 1   TXN-20240412-000001       2024-04-12  2024      4      April      Q2
# 2   TXN-20220128-000002       2022-01-28  2022      1    January      Q1
# 3   TXN-20201012-000003       2020-10-12  2020     10    October      Q4
# 4   TXN-20211127-000004       2021-11-27  2021     11   November      Q4
# 5   TXN-20210505-000005       2021-05-05  2021      5        May      Q2
# 6   TXN-20200213-000006       2020-02-13  2020      2   February      Q1
# 7   TXN-20200720-000007       2020-07-20  2020      7       July      Q3
# 8   TXN-20220215-000008       2022-02-15  2022      2   February      Q1
# 9   TXN-20200902-000009       2020-09-02  2020      9  September      Q3
# 10  TXN-20241205-000010       2024-12-05  2024     12   December      Q4
# 11  TXN-20200331-000011       2020-03-31  2020      3      March      Q1
# 12  TXN-20220412-000012       2022-04-12  2022      4      April      Q2
# 13  TXN-20241105-000013       2024-11-05  2024     11   November      Q4
# 14  TXN-20231005-000014       2023-10-05  2023     10    October      Q4
# 15  TXN-20230902-000015       2023-09-02  2023      9  September      Q3
# 16  TXN-20220329-000016       2022-03-29  2022      3      March      Q1
# 17  TXN-20240417-000017       2024-04-17  2024      4      April      Q2
# 18  TXN-20220218-000018       2022-02-18  2022      2   February      Q1
# 19  TXN-20211101-000019       2021-11-01  2021     11   November      Q4
# 20  TXN-20210322-000020       2021-03-22  2021      3      March      Q1
# 21  TXN-20230916-000021       2023-09-16  2023      9  September      Q3
# 22  TXN-20241210-000022       2024-12-10  2024     12   December      Q4
# 23  TXN-20220408-000023       2022-04-08  2022      4      April      Q2
# 24  TXN-20210201-000024       2021-02-01  2021      2   February      Q1
# 25  TXN-20240719-000025       2024-07-19  2024      7       July      Q3
# 26  TXN-20210419-000026       2021-04-19  2021      4      April      Q2
# 27  TXN-20210711-000027       2021-07-11  2021      7       July      Q3
# 28  TXN-20211019-000028       2021-10-19  2021     10    October      Q4
# 29  TXN-20200925-000029       2020-09-25  2020      9  September      Q3
# 30  TXN-20230512-000030       2023-05-12  2023      5        May      Q2
# 31  TXN-20220826-000031       2022-08-26  2022      8     August      Q3
# 32  TXN-20220217-000032       2022-02-17  2022      2   February      Q1
# 33  TXN-20201224-000033       2020-12-24  2020     12   December      Q4
# 34  TXN-20230317-000034       2023-03-17  2023      3      March      Q1
# 35  TXN-20230709-000035       2023-07-09  2023      7       July      Q3
# 36  TXN-20240123-000036       2024-01-23  2024      1    January      Q1
# 37  TXN-20200826-000037       2020-08-26  2020      8     August      Q3
# 38  TXN-20220122-000038       2022-01-22  2022      1    January      Q1
# 39  TXN-20230111-000039       2023-01-11  2023      1    January      Q1
# 40  TXN-20210909-000040       2021-09-09  2021      9  September      Q3
# 41  TXN-20230826-000041       2023-08-26  2023      8     August      Q3
# 42  TXN-20200907-000042       2020-09-07  2020      9  September      Q3
# 43  TXN-20231121-000043       2023-11-21  2023     11   November      Q4
# 44  TXN-20231012-000044       2023-10-12  2023     10    October      Q4
# 45  TXN-20220217-000045       2022-02-17  2022      2   February      Q1
# 46  TXN-20240925-000046       2024-09-25  2024      9  September      Q3
# 47  TXN-20221008-000047       2022-10-08  2022     10    October      Q4
# 48  TXN-20240222-000048       2024-02-22  2024      2   February      Q1
# 49  TXN-20211116-000049       2021-11-16  2021     11   November      Q4
#
#    day_of_week         brand     brand_type        product_category  ...  \
# 0    Wednesday       OK Play          Local               STEM Toys  ...
# 1       Friday          Lego  International           Arts & Crafts  ...
# 2       Friday      Funskool  International             Board Games  ...
# 3       Monday        Hasbro  International               Soft Toys  ...
# 4     Saturday  Fisher Price  International       Construction Toys  ...
# 5    Wednesday      Funskool  International  Dolls & Action Figures  ...
# 6     Thursday          Lego  International       Construction Toys  ...
# 7       Monday      Funskool  International               STEM Toys  ...
# 8      Tuesday          Nerf  International                Vehicles  ...
# 9    Wednesday    Hot Wheels  International  Dolls & Action Figures  ...
# 10    Thursday  Fisher Price  International            Outdoor Toys  ...
# 11     Tuesday      Toy Zone          Local             Board Games  ...
# 12     Tuesday       OK Play          Local               Soft Toys  ...
# 13     Tuesday    Hot Wheels  International               Soft Toys  ...
# 14    Thursday        Barbie  International           Arts & Crafts  ...
# 15    Saturday        Barbie  International               STEM Toys  ...
# 16     Tuesday      Funskool          Local  Dolls & Action Figures  ...
# 17   Wednesday  Fisher Price  International  Dolls & Action Figures  ...
# 18      Friday      Toy Zone          Local               Soft Toys  ...
# 19      Monday          Nerf  International               Soft Toys  ...
# 20      Monday        Hasbro  International             Board Games  ...
# 21    Saturday        Hasbro  International       Construction Toys  ...
# 22     Tuesday   Skillmatics          Local           Arts & Crafts  ...
# 23      Friday      Toy Zone          Local                Vehicles  ...
# 24      Monday        Hasbro  International       Construction Toys  ...
# 25      Friday      Funskool  International               Soft Toys  ...
# 26      Monday          Nerf  International                Vehicles  ...
# 27      Sunday          Lego  International               Soft Toys  ...
# 28     Tuesday        Barbie  International                Vehicles  ...
# 29      Friday     Playshifu          Local  Dolls & Action Figures  ...
# 30      Friday          Nerf  International               Soft Toys  ...
# 31      Friday       OK Play          Local                Vehicles  ...
# 32    Thursday     Playshifu          Local       Construction Toys  ...
# 33    Thursday       OK Play          Local                Vehicles  ...
# 34      Friday        Barbie  International            Outdoor Toys  ...
# 35      Sunday      Funskool          Local           Arts & Crafts  ...
# 36     Tuesday      Toy Zone          Local  Dolls & Action Figures  ...
# 37   Wednesday      Toy Zone          Local                Vehicles  ...
# 38    Saturday        Mattel  International  Dolls & Action Figures  ...
# 39   Wednesday          Nerf  International       Construction Toys  ...
# 40    Thursday      Funskool          Local                Vehicles  ...
# 41    Saturday        Mattel  International               Soft Toys  ...
# 42      Monday   Skillmatics          Local       Construction Toys  ...
# 43     Tuesday        Barbie  International            Outdoor Toys  ...
# 44    Thursday  Fisher Price  International                Vehicles  ...
# 45    Thursday        Barbie  International           Arts & Crafts  ...
# 46   Wednesday  Fisher Price  International  Dolls & Action Figures  ...
# 47    Saturday    Hot Wheels  International                Vehicles  ...
# 48    Thursday       OK Play          Local           Arts & Crafts  ...
# 49     Tuesday        Barbie  International               Soft Toys  ...
#
#    unit_price_inr quantity gross_revenue_inr discount_percentage  \
# 0         3309.05        4          13236.20                0.00
# 1          602.82        3           1808.46                0.00
# 2         3171.93        1           3171.93                0.00
# 3         1756.13        1           1756.13                0.00
# 4         3616.34        2           7232.68                0.00
# 5         2828.14        1           2828.14                0.00
# 6         2304.67        1           2304.67               10.95
# 7         6832.50        1           6832.50                0.00
# 8          443.22        1            443.22                0.00
# 9         1436.78        1           1436.78               22.90
# 10        7059.53        1           7059.53                0.00
# 11        1056.55        1           1056.55                6.88
# 12         915.26        1            915.26                0.00
# 13         659.78        2           1319.56               29.06
# 14        1654.11        1           1654.11                0.00
# 15       10946.26        1          10946.26               21.60
# 16        1011.30        1           1011.30                0.00
# 17        4042.30        1           4042.30                0.00
# 18        2081.43        3           6244.29               15.90
# 19         660.73        1            660.73                0.00
# 20        1554.52        4           6218.08                5.64
# 21        4712.29        1           4712.29                0.00
# 22        1973.45        1           1973.45                0.00
# 23        1565.97        2           3131.94               22.57
# 24        2650.37        1           2650.37               28.60
# 25        2037.45        1           2037.45                0.00
# 26        5631.77        1           5631.77                0.00
# 27        2201.70        2           4403.40               21.86
# 28         721.86        3           2165.58                7.20
# 29        2232.68        3           6698.04                0.00
# 30         807.32        3           2421.96               12.46
# 31        2262.63        2           4525.26                0.00
# 32        1829.38        2           3658.76                0.00
# 33         510.65        1            510.65                0.00
# 34        8080.24        2          16160.48               26.63
# 35         511.20        2           1022.40                0.00
# 36        2761.62        1           2761.62                0.00
# 37        1283.63        1           1283.63                0.00
# 38        4228.02        2           8456.04                0.00
# 39        1360.20        1           1360.20                0.00
# 40        1534.04        1           1534.04                0.00
# 41        2034.81        1           2034.81                0.00
# 42        4483.03        1           4483.03                0.00
# 43        4446.90        1           4446.90                0.00
# 44        4967.54        1           4967.54               15.75
# 45        1936.55        1           1936.55                0.00
# 46        3333.15        4          13332.60                0.00
# 47        2734.81        1           2734.81               16.72
# 48         439.41        1            439.41               27.48
# 49        3591.58        2           7183.16                0.00
#
#    discount_amount_inr net_revenue_inr customer_rating safety_certified  \
# 0                 0.00        13236.20             3.4              Yes
# 1                 0.00         1808.46             4.1              NaN
# 2                 0.00         3171.93             4.3              Yes
# 3                 0.00         1756.13             3.6              Yes
# 4                 0.00         7232.68             4.7               No
# 5                 0.00         2828.14             4.1              NaN
# 6               252.36         2052.31             4.8              Yes
# 7                 0.00         6832.50             4.2              Yes
# 8                 0.00          443.22             4.1              Yes
# 9               329.02         1107.76             4.4               No
# 10                0.00         7059.53             3.9              Yes
# 11               72.69          983.86             3.6              Yes
# 12                0.00          915.26             3.6              Yes
# 13              383.46          936.10             3.3              Yes
# 14                0.00         1654.11             4.3               No
# 15             2364.39         8581.87             4.6              Yes
# 16                0.00         1011.30             4.2              Yes
# 17                0.00         4042.30             4.1              Yes
# 18              992.84         5251.45             4.2               No
# 19                0.00          660.73             3.8              Yes
# 20              350.70         5867.38             3.4               No
# 21                0.00         4712.29             3.9               No
# 22                0.00         1973.45             4.0               No
# 23              706.88         2425.06             3.0               No
# 24              758.01         1892.36             4.4               No
# 25                0.00         2037.45             3.4               No
# 26                0.00         5631.77             4.1              NaN
# 27              962.58         3440.82             3.4              Yes
# 28              155.92         2009.66             3.7              Yes
# 29                0.00         6698.04             4.0               No
# 30              301.78         2120.18             4.5               No
# 31                0.00         4525.26             3.2               No
# 32                0.00         3658.76             4.1               No
# 33                0.00          510.65             4.3               No
# 34             4303.54        11856.94             3.2              Yes
# 35                0.00         1022.40             3.4              Yes
# 36                0.00         2761.62             4.3               No
# 37                0.00         1283.63             3.4               No
# 38                0.00         8456.04             3.7               No
# 39                0.00         1360.20             3.9               No
# 40                0.00         1534.04             4.0              Yes
# 41                0.00         2034.81             3.6               No
# 42                0.00         4483.03             4.0               No
# 43                0.00         4446.90             4.8              Yes
# 44              782.39         4185.15             4.6               No
# 45                0.00         1936.55             4.5              Yes
# 46                0.00        13332.60             3.2              Yes
# 47              457.26         2277.55             3.7               No
# 48              120.75          318.66             4.3              Yes
# 49                0.00         7183.16             4.1              Yes
#
#     returned  customer_type
# 0         No            New
# 1         No      Returning
# 2        Yes      Returning
# 3        Yes      Returning
# 4         No      Returning
# 5         No      Returning
# 6         No      Returning
# 7        Yes      Returning
# 8        Yes            New
# 9         No      Returning
# 10        No      Returning
# 11       Yes      Returning
# 12        No            New
# 13       Yes      Returning
# 14       Yes      Returning
# 15       Yes      Returning
# 16        No      Returning
# 17        No      Returning
# 18        No      Returning
# 19       NaN      Returning
# 20        No      Returning
# 21        No      Returning
# 22        No      Returning
# 23        No      Returning
# 24       Yes      Returning
# 25        No            New
# 26        No      Returning
# 27       NaN      Returning
# 28       NaN            NaN
# 29       Yes      Returning
# 30        No      Returning
# 31        No            New
# 32       NaN            New
# 33        No      Returning
# 34        No      Returning
# 35       Yes      Returning
# 36        No      Returning
# 37        No      Returning
# 38       Yes      Returning
# 39        No      Returning
# 40       Yes            New
# 41       Yes      Returning
# 42       Yes      Returning
# 43       Yes            New
# 44       Yes            New
# 45        No      Returning
# 46       Yes      Returning
# 47       Yes            New
# 48       Yes            New
# 49       Yes      Returning
#
# [50 rows x 28 columns]

# %%
# downloading the cleaned data 
df.to_csv(r"C:\Users\lenovo\Downloads\indian toys\cleaned_indian_toy_market_sales_data.csv")
